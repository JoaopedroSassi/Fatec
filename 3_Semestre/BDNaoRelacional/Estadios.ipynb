# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install mongo
from pymongo import MongoClient
# Out:
# Requirement already satisfied: mongo in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (from mongo) (4.6.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo->mongo) (2.4.2)

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_Banco_de_Dados_NoSQL/main/material%20de%20apoio/base%20de%20dados/Coordenadas%20csv.csv"

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente = MongoClient("mongodb+srv://BDNAORELACIONAL:BvIUjuXasKF6EPP4@cluster0.4xpz7tt.mongodb.net/?retryWrites=true&w=majority")

# %%
db = cliente.get_database('estadiosFutebol')

# %%
db
# Out:
# Database(MongoClient(host=['ac-jq4kupv-shard-00-00.4xpz7tt.mongodb.net:27017', 'ac-jq4kupv-shard-00-01.4xpz7tt.mongodb.net:27017', 'ac-jq4kupv-shard-00-02.4xpz7tt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1499ze-shard-0', tls=True), 'estadiosFutebol')

# %%
db.estadiosJoao.find()

# %%
list(db.estadiosJoao.find())
# Out:
# []

# %%
db.estadiosJoao.delete_many({})
# Out:
# DeleteResult({'n': 73, 'electionId': ObjectId('7fffffff00000000000000bf'), 'opTime': {'ts': Timestamp(1699581394, 79), 't': 191}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1699581394, 79), 'signature': {'hash': b'\x07\xaa:\xe2<\x07\xc0}"\xc1\x97\xa9\x9d\x85B\x91\xaa\x17t\xfd', 'keyId': 7255339509825404930}}, 'operationTime': Timestamp(1699581394, 79)}, acknowledged=True)

# %%
db.estadiosJoao.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('654d8ddd2a555a3dd90cb2e8'), ObjectId('654d8ddd2a555a3dd90cb2e9'), ObjectId('654d8ddd2a555a3dd90cb2ea'), ObjectId('654d8ddd2a555a3dd90cb2eb'), ObjectId('654d8ddd2a555a3dd90cb2ec'), ObjectId('654d8ddd2a555a3dd90cb2ed'), ObjectId('654d8ddd2a555a3dd90cb2ee'), ObjectId('654d8ddd2a555a3dd90cb2ef'), ObjectId('654d8ddd2a555a3dd90cb2f0'), ObjectId('654d8ddd2a555a3dd90cb2f1'), ObjectId('654d8ddd2a555a3dd90cb2f2'), ObjectId('654d8ddd2a555a3dd90cb2f3'), ObjectId('654d8ddd2a555a3dd90cb2f4'), ObjectId('654d8ddd2a555a3dd90cb2f5'), ObjectId('654d8ddd2a555a3dd90cb2f6'), ObjectId('654d8ddd2a555a3dd90cb2f7'), ObjectId('654d8ddd2a555a3dd90cb2f8'), ObjectId('654d8ddd2a555a3dd90cb2f9'), ObjectId('654d8ddd2a555a3dd90cb2fa'), ObjectId('654d8ddd2a555a3dd90cb2fb')], acknowledged=True)

# %%
estadios = db.estadiosJoao

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['ac-jq4kupv-shard-00-00.4xpz7tt.mongodb.net:27017', 'ac-jq4kupv-shard-00-01.4xpz7tt.mongodb.net:27017', 'ac-jq4kupv-shard-00-02.4xpz7tt.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-1499ze-shard-0', tls=True), 'estadiosFutebol'), 'estadiosJoao')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('654d8ddd2a555a3dd90cb2e8'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2e9'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2ea'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2eb'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2ec'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2ed'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2ee'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2ef'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f0'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f1'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f2'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f3'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f4'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f5'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f6'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f7'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f8'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2f9'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2fa'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('654d8ddd2a555a3dd90cb2fb'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat = -14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           654d8ddd2a555a3dd90cb2e8
# nome                          Maracanã
# capacidade                       78838
# latitude                     -22.90981
# longitude                    -43.23391
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location = [center_lat, center_lon], zoom_start = 5, width = 800, height = 600)

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 20

# %%
for i in range(qtde):
  lng = float(df_convertido.iloc[i]['longitude'])
  lat = float(df_convertido.iloc[i]['latitude'])
  description = 'Estádio: ' + str(df_convertido.iloc[i]['nome']) + '<br> Capacidade: ' + str(df_convertido.iloc[i]['capacidade'])
  folium.Marker([lat, lng],
                popup = description,
                icon = folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d219f3aad59acc96a0bdf491df843854 {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d219f3aad59acc96a0bdf491df843854&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d219f3aad59acc96a0bdf491df843854 = L.map(
#                 &quot;map_d219f3aad59acc96a0bdf491df843854&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6502490d3550ca523a5a97b5533cd84 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d219f3aad59acc96a0bdf491df843854);
#
#
#             var marker_687294252ac108ae9e037d2f468ddd30 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_d219f3aad59acc96a0bdf491df843854);
#
#
#             var icon_0e4fe681bc36ce3277b2984243411976 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_687294252ac108ae9e037d2f468ddd30.setIcon(icon_0e4fe681bc36ce3277b2984243411976);
#
#
#         var popup_2579895bdf1f778e52ce084b9bdcadd7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8723cceeb8829aff97f6d3b80734f5de = $(`&lt;div id=&quot;html_8723cceeb8829aff97f6d3b80734f5de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_2579895bdf1f778e52ce084b9bdcadd7.setContent(html_8723cceeb8829aff97f6d3b80734f5de);
#
#
#
#         marker_687294252ac108ae9e037d2f468ddd30.bindPopup(popup_2579895bdf1f778e52ce084b9bdcadd7)
#         ;
#
#
#
#
#             var marker_ddcc2cff439bca7db2681762dd37fdd1 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_d219f3aad59acc96a0bdf491df843854);
#
#
#             var icon_0f7597b13ddac60bdf5de12d9e42e325 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ddcc2cff439bca7db2681762dd37fdd1.setIcon(icon_0f7597b13ddac60bdf5de12d9e42e325);
#
#
#         var popup_45c3a2506bdeda55d43d7cb282ea0785 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5aacb5e9967bb2830bec3c1ab09e1a30 = $(`&lt;div id=&quot;html_5aacb5e9967bb2830bec3c1ab09e1a30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_45c3a2506bdeda55d43d7cb282ea0785.setContent(html_5aacb5e9967bb2830bec3c1ab09e1a30);
#
#
#
#         marker_ddcc2cff439bca7db2681762dd37fdd1.bindPopup(popup_45c3a2506bdeda55d43d7cb282ea0785)
#         ;
#
#
#
#
#             var marker_0448604511b775f51219325860cc4788 = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_d219f3aad59acc96a0bdf491df843854);
#
#
#             var icon_da2afb89c2e635158695d93f5636d4fb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0448604511b775f51219325860cc4788.setIcon(icon_da2afb89c2e635158695d93f5636d4fb);
#
#
#         var popup_cd4ae1df974b9b7f7dc37a342d9e3046 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bf2a390009e2b7bab5a3d7c7eb43c825 = $(`&lt;div id=&quot;html_bf2a390009e2b7bab5a3d7c7eb43c825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Morumbi&lt;br&gt; Capacidade: 66795&lt;/div&gt;`)[0];
#                 popup_cd4ae1df974b9b7f7dc37a342d9e3046.setContent(html_bf2a390009e2b7bab5a3d7c7eb43c825);
#
#
#
#         marker_0448604511b775f51219325860cc4788.bindPopup(popup_cd4ae1df974b9b7f7dc37a342d9e3046)
#         ;
#
#
#
#
#             var marker_f1f31c912503d09a1e65e39a3463c61d = L.marker(
#                 [-3.80674, -38.52168],
#                 {}
#             ).addTo(map_d219f3aad59acc96a0bdf491df843854);
#
#
#             var icon_ecfdd1bb91a7280aa45028d74dfc4b24 = L.AwesomeMarkers.ico
